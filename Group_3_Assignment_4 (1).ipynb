# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set file path to a variable
input_file_path = r"C:\Users\Niyati\OneDrive\Documents\DATA_TOOLS\youtube_dataset.csv"

# %%
# Read Data into a DataFrame
df = pd.read_csv(input_file_path)

# %%
#Check the data
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
#Create a function to calculate the distribution of channeltype from the top 1000 records and Load only the top 1000 records of the original 4000 into a separate CSV file, and to a database table.
df_top_thousand=df.iloc[:1000,:]
df_top_thousand

def cal_distribution(df,groupfilter):
    print(df[groupfilter].value_counts())
    df[groupfilter].value_counts().plot(kind='bar', color='blue')
    
cal_distribution(top_thousand, 'channeltype')
df_top_thousand.to_csv('new_channel_Type_top_1000.csv')
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64
